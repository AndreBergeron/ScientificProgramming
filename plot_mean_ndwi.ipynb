# %% [markdown]
# ## 2: Plot a Sample NDWI Time Series

# %%
from shapely.geometry import shape
from dask.distributed import Client, LocalCluster
cluster = LocalCluster(n_workers=5, memory_limit='4GB')
client = Client(cluster)
client
# Out:
# <Client: 'tcp://127.0.0.1:43665' processes=5 threads=10, memory=18.63 GiB>

# %%
original_bbox = {
  "type": "FeatureCollection",
  "features": [
    {
      "type": "Feature",
      "properties": {},
      "geometry": {
      "coordinates": [
          [
            [
              37.48171911932283,
              12.09646539241534
            ],
            [
              37.48171911932283,
              11.962224220348077
            ],
            [
              37.656944179348955,
              11.962224220348077
            ],
            [
              37.656944179348955,
              12.09646539241534
            ],
            [
              37.48171911932283,
              12.09646539241534
            ]
          ]
        ],
        "type": "Polygon"
      }
    }
  ]
}

geom = shape(original_bbox["features"][0]["geometry"])
lon_min, lat_min, lon_max, lat_max = geom.bounds

bbox = (lon_min, lat_min, lon_max, lat_max)

# %%
from assign5script import main

# %%
main(bbox=bbox, starttime = "2020-01-01", endtime = "2024-12-31", filter_clouds=False)

# %% [markdown]
# ## 3: Filter Cloudy Pixels

# %%
main(bbox=bbox, starttime="2020-01-01", endtime="2024-12-31", filter_clouds=True)
